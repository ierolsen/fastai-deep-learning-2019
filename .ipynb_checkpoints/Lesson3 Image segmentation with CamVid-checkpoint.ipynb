# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

# %%
path = untar_data(URLs.CAMVID)
path.ls()
# Out:
# [WindowsPath('C:/Users/my/.fastai/data/camvid/codes.txt'),
#  WindowsPath('C:/Users/my/.fastai/data/camvid/images'),
#  WindowsPath('C:/Users/my/.fastai/data/camvid/labels'),
#  WindowsPath('C:/Users/my/.fastai/data/camvid/valid.txt')]

# %%
path_lbl = path/'labels'
path_img = path/'images'

# %% [markdown]
# ### Data

# %%
fnames = get_image_files(path_img)
fnames[:3]
# Out:
# [WindowsPath('C:/Users/my/.fastai/data/camvid/images/0001TP_006690.png'),
#  WindowsPath('C:/Users/my/.fastai/data/camvid/images/0001TP_006720.png'),
#  WindowsPath('C:/Users/my/.fastai/data/camvid/images/0001TP_006750.png')]

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:3]
# Out:
# [WindowsPath('C:/Users/my/.fastai/data/camvid/labels/0001TP_006690_P.png'),
#  WindowsPath('C:/Users/my/.fastai/data/camvid/labels/0001TP_006720_P.png'),
#  WindowsPath('C:/Users/my/.fastai/data/camvid/labels/0001TP_006750_P.png')]

# %%
img_f = fnames[0]
img = open_image(img_f)
img.show(figsize=(5,5))

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([720, 960]), tensor([[[ 4,  4,  4,  ...,  4,  4,  4],
#           [ 4,  4,  4,  ...,  4,  4,  4],
#           [ 4,  4,  4,  ...,  4,  4,  4],
#           ...,
#           [19, 19, 19,  ..., 30, 30, 30],
#           [19, 19, 19,  ..., 30, 30, 30],
#           [19, 19, 19,  ..., 30, 30, 30]]]))

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %% [markdown]
# ### Datasets

# %%
size = src_size//2

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=2
else:           bs=1
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# using bs=1, have 4021MB of GPU RAM free

# %%
src = (SegmentationItemList.from_folder(path_img)
       .split_by_fname_file('../valid.txt')
       .label_from_func(get_y_fn, classes=codes))

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# ### Model

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='69' class='' max='600', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.50% [69/600 01:25<10:56 3.3808]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(10, slice(3e-3), pct_start=0.9)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.826368</td>
#       <td>0.665139</td>
#       <td>0.830213</td>
#       <td>05:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.741756</td>
#       <td>0.591730</td>
#       <td>0.838821</td>
#       <td>05:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.641756</td>
#       <td>0.646424</td>
#       <td>0.844817</td>
#       <td>05:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.588801</td>
#       <td>0.528825</td>
#       <td>0.851961</td>
#       <td>05:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.594438</td>
#       <td>0.687278</td>
#       <td>0.850025</td>
#       <td>05:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.665738</td>
#       <td>0.564772</td>
#       <td>0.850078</td>
#       <td>05:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.603313</td>
#       <td>0.541983</td>
#       <td>0.865791</td>
#       <td>05:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.686446</td>
#       <td>0.724798</td>
#       <td>0.808861</td>
#       <td>05:02</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.559157</td>
#       <td>0.551915</td>
#       <td>0.856464</td>
#       <td>05:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.477701</td>
#       <td>0.453521</td>
#       <td>0.871523</td>
#       <td>05:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.unfreeze()

# %%
lr=3e-3

lrs = slice(lr/400,lr/4)

# %%
learn.fit_one_cycle(12, lrs, pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.433963</td>
#       <td>0.429723</td>
#       <td>0.876308</td>
#       <td>05:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.457600</td>
#       <td>0.409959</td>
#       <td>0.881344</td>
#       <td>05:32</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.424209</td>
#       <td>0.427711</td>
#       <td>0.874783</td>
#       <td>05:28</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.435767</td>
#       <td>0.407344</td>
#       <td>0.880228</td>
#       <td>05:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.449032</td>
#       <td>0.408311</td>
#       <td>0.884425</td>
#       <td>05:33</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.432426</td>
#       <td>0.386422</td>
#       <td>0.883998</td>
#       <td>05:35</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.439275</td>
#       <td>0.408015</td>
#       <td>0.885233</td>
#       <td>05:32</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.414379</td>
#       <td>0.416133</td>
#       <td>0.876253</td>
#       <td>05:32</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.405134</td>
#       <td>0.403118</td>
#       <td>0.888464</td>
#       <td>05:32</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.414262</td>
#       <td>0.359958</td>
#       <td>0.898200</td>
#       <td>05:33</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.371029</td>
#       <td>0.340031</td>
#       <td>0.901160</td>
#       <td>05:31</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.336604</td>
#       <td>0.334469</td>
#       <td>0.906006</td>
#       <td>05:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.save('stage-2');
